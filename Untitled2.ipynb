# %%
import pandas as pd
dataset = pd.read_csv('dataset - Copy.csv')
dataset
# Out:
#                                                  title  \
# 0    Between Two Fires: American Indians in the Civ...
# 1                             Fashion Sourcebook 1920s
# 2                                           Hungary 56
# 3    All-American Anarchist: Joseph A. Labadie and ...
# 4                                Les oiseaux gourmands
# ..                                                 ...
# 494  The Arthur of Medieval Latin Literature: The D...
# 495  The Arthur of the North: The Arthurian Legend ...
# 496  Artful Journals: Making and Embellishing Memor...
# 497                    Onward Towards Our Noble Deaths
# 498                               Chinese Erotic Poems
#
#                                                  genre  \
# 0    History,Military History,Civil War,American Hi...
# 1            Couture,Fashion,Historical,Art,Nonfiction
# 2                                     Politics,History
# 3                                        Labor,History
# ...

# %%
X = pd.DataFrame(dataset.iloc[:,1:8])
y = pd.DataFrame(dataset.iloc[:,0])

# %%
X
# Out:
#                                                  genre  \
# 0    History,Military History,Civil War,American Hi...
# 1            Couture,Fashion,Historical,Art,Nonfiction
# 2                                     Politics,History
# 3                                        Labor,History
# 4    Business,Leadership,Romance,Historical Romance...
# ..                                                 ...
# 494  Poetry,Adult Fiction,Erotica,Cultural,China,Li...
# 495  Science,Engineering,Reference,Nonfiction,Compu...
# 496  Fiction,Classics,European Literature,British L...
# 497  Category Romance,Harlequin,Romance,Harlequin,H...
# 498  Young Adult,Adventure,Contemporary,Mystery,You...
#
#                                            description  \
# 0    Reveals that several hundred thousand Indians ...
# 1    Fashion Sourcebook - 1920s is the first book i...
# 2    The seminal history and analysis of the Hungar...
# 3    "All-American Anarchist" chronicles the life a...
# ...

# %%
y
# Out:
#                                                  title
# 0    Between Two Fires: American Indians in the Civ...
# 1                             Fashion Sourcebook 1920s
# 2                                           Hungary 56
# 3    All-American Anarchist: Joseph A. Labadie and ...
# 4                                Les oiseaux gourmands
# ..                                                 ...
# 494  The Arthur of Medieval Latin Literature: The D...
# 495  The Arthur of the North: The Arthurian Legend ...
# 496  Artful Journals: Making and Embellishing Memor...
# 497                    Onward Towards Our Noble Deaths
# 498                               Chinese Erotic Poems
#
# [499 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train,test_size=0.4, random_state=1)

# %%
X = X_train.values.astype(np.float64)
y = y_train.values.astype(np.float64)

# %%
from sklearn.tree import DecisionTreeClassifier
logmodel = DecisionTreeClassifier()
y_predict = logmodel.fit(X, y).predict(X_test)
# Out:
# c:\users\shiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 3>()
#       1 from sklearn.metrics import classification_report, confusion_matrix
# ----> 3 print(confusion_matrix(y_test, y_predict))
#
# File c:\users\shiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:309, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     307 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308 if y_type not in ("binary", "multiclass"):
# --> 309     raise ValueError("%s is not supported" % y_type)
#     311 if labels is None:
#     312     labels = unique_labels(y_true, y_pred)
#
# ValueError: multilabel-indicator is not supported
